# %%
### Run this cell before continuing.
import altair as alt
import numpy as np
import pandas as pd
from sklearn import set_config
from sklearn.compose import make_column_transformer
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    cross_validate,
    train_test_split,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Simplify working with large datasets in Altair
alt.data_transformers.enable('vegafusion')

# Output dataframes instead of arrays
set_config(transform_output="pandas")

# %%
url = "https://raw.githubusercontent.com/agallagh/DSCI-Project/refs/heads/main/players.csv"
players_data = pd.read_csv(url)
players_data
# Out:
#     experience  subscribe                                        hashedEmail  \
# 0          Pro       True  f6daba428a5e19a3d47574858c13550499be23603422e6...
# 1      Veteran       True  f3c813577c458ba0dfef80996f8f32c93b6e8af1fa9397...
# 2      Veteran      False  b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3...
# 3      Amateur       True  23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4f...
# 4      Regular       True  7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb...
# ..         ...        ...                                                ...
# 191    Amateur       True  b6e9e593b9ec51c5e335457341c324c34a2239531e1890...
# 192    Veteran      False  71453e425f07d10da4fa2b349c83e73ccdf0fb3312f778...
# 193    Amateur      False  d572f391d452b76ea2d7e5e53a3d38bfd7499c7399db29...
# 194    Amateur      False  f19e136ddde68f365afc860c725ccff54307dedd13968e...
# 195        Pro       True  d9473710057f7d42f36570f0be83817a4eea614029ff90...
#
#      played_hours       name             gender  age  individualId  \
# 0            30.3     Morgan               Male    9           NaN
# 1             3.8  Christian               Male   17           NaN
# 2             0.0      Blake               Male   17           NaN
# 3             0.7      Flora             Female   21           NaN
# 4             0.1      Kylie               Male   21           NaN
# ..            ...        ...                ...  ...           ...
# 191           0.0     Bailey             Female   17           NaN
# 192           0.3     Pascal               Male   22           NaN
# 193           0.0      Dylan  Prefer not to say   17           NaN
# 194           2.3     Harlow               Male   17           NaN
# 195           0.2      Ahmed              Other   91           NaN
#
#      organizationName
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 191               NaN
# 192               NaN
# 193               NaN
# 194               NaN
# 195               NaN
#
# [196 rows x 9 columns]

# %%
# tidying the data by dropping the unecessary columns

tidy_players = players_data[["experience", "played_hours", "age"]]
tidy_players

# filtering data in age column for our demographic (age less than 60)

filtered_age_df = tidy_players[tidy_players["age"] < 60]
filtered_age_df
# Out:
#     experience  played_hours  age
# 0          Pro          30.3    9
# 1      Veteran           3.8   17
# 2      Veteran           0.0   17
# 3      Amateur           0.7   21
# 4      Regular           0.1   21
# ..         ...           ...  ...
# 190    Amateur           0.0   20
# 191    Amateur           0.0   17
# 192    Veteran           0.3   22
# 193    Amateur           0.0   17
# 194    Amateur           2.3   17
#
# [194 rows x 3 columns]

# %%
#filtering played hours to under 100 to remove outliers

filtered_hrs_df = filtered_age_df[filtered_age_df["played_hours"] < 100]

# %%
np.random.seed(3131) 

#Train model

# split the train/test data: 75% train, 25% test
player_train, player_test = train_test_split(filtered_hrs_df, train_size = 0.75, random_state = 3131)

# make X/y objects
X_train = player_train[['played_hours',	'age']]
y_train = player_train['experience']

# make X/y testing objects
X_test = player_test[['played_hours',	'age']]
y_test = player_test['experience']


# make a preprocessor for the hours played and age columns
# player_preprocessor = make_column_transformer(
#     (StandardScaler(), ['played_hours',	'age']),
#      remainder='passthrough',
#     verbose_feature_names_out = False
#)

#fit the data to the 

#knn_spec = KNeighborsClassifier(n_neighbors = n, random_seed = 2000)

# %%
knn_spec = KNeighborsClassifier()

param_grid = {
    "n_neighbors": range(2, 16, 1),
}

knn_tune_grid = GridSearchCV(
    knn_spec, param_grid, return_train_score=True, n_jobs=-1, cv=5
)

knn_model_grid = knn_tune_grid.fit(X_train, y_train)

accuracies_grid = pd.DataFrame(knn_model_grid.cv_results_)

cross_val_plot = alt.Chart(accuracies_grid).mark_line(point=True).encode(
    x=alt.X("param_n_neighbors").title("Number of neighbours").scale(zero=False),
    y=alt.Y("mean_test_score").title("Mean test score").scale(zero=False)
)

cross_val_plot
# Out:
# alt.Chart(...)

# %%
#explain which is best, confirm with 
knn_tune_grid.best_params_['n_neighbors']
# Out:
# 6

# %%
np.random.seed(3131)

# testing accuracy
model_accuracy = knn_model_grid.score(X_test, y_test)

#something else
knn_best = KNeighborsClassifier(knn_tune_grid.best_params_['n_neighbors'])

player_preprocessor = make_column_transformer(
    (StandardScaler(), ['played_hours',	'age']),
     remainder='passthrough',
    verbose_feature_names_out = False
)

players_test_fit = make_pipeline(player_preprocessor, knn_best).fit(X_test, y_test)


player_test_predictions = player_test.assign(
    predicted=players_test_fit.predict(X_test)
)

player_test_predictions
# Out:
#     experience  played_hours  age predicted
# 139    Veteran           0.0   20   Veteran
# 100    Amateur           0.0   20   Veteran
# 29     Veteran           0.1   18   Veteran
# 53     Amateur           0.2   27  Beginner
# 37     Amateur           0.2   17   Amateur
# 184        Pro           1.7   17  Beginner
# 20     Regular           0.3    8   Amateur
# 127    Amateur           0.0   21   Veteran
# 168    Veteran           0.1   17   Veteran
# 81     Veteran           1.0   17   Amateur
# 135    Veteran           0.0   21   Veteran
# 94    Beginner           0.8   22   Veteran
# 146        Pro           0.0   25   Amateur
# 31     Veteran           0.1   21   Veteran
# 6      Regular           0.0   19   Veteran
# 118    Veteran           0.0   46  Beginner
# 46     Veteran           0.1   17   Veteran
# 43     Veteran           0.0   21   Veteran
# 50     Veteran           0.6   21   Veteran
# 18     Amateur           0.5   17   Amateur
# 96     Amateur           0.1   19   Veteran
# 186    Veteran           0.1   44  Beginner
# 165    Regular           0.1   21   Veteran
# 151    Amateur           0.0   17   Veteran
# 107    Veteran           2.7   22   Veteran
# 45    Beginner           0.0   24  Beginner
# 159   Beginner           0.0   22   Veteran
# 38     Veteran           0.0   17   Veteran
# 142   Beginner           1.0   17   Amateur
# 149    Amateur           0.0   16   Amateur
# 75     Amateur           0.5   21   Veteran
# 176        Pro           0.0   17   Veteran
# 40     Regular           5.6   17   Veteran
# 35     Veteran           0.4   20   Veteran
# 172    Veteran           0.0   20   Veteran
# 177    Veteran           2.7   21   Veteran
# 26     Regular           0.0   17   Veteran
# 99         Pro           0.5   12   Amateur
# 175    Amateur           0.3   17   Amateur
# 22    Beginner           1.0   17   Amateur
# 69     Regular           0.0   21   Veteran
# 88    Beginner           0.0   17   Veteran
# 21     Amateur           0.1   17   Veteran
# 41     Veteran           0.1   17   Veteran
# 82    Beginner           0.2   37  Beginner
# 2      Veteran           0.0   17   Veteran
# 138    Veteran           0.0   17   Veteran
# 36     Veteran           1.4   25   Amateur
